# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Unpack the coordinates list
coordinates = list(lat_lngs)

# %%
#Import dependencies
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 89.64,
#   'feels_like': 98.28,
#   'temp_min': 82.94,
#   'temp_max': 94.39,
#   'pressure': 1005,
#   'humidity': 59},
#  'visibility': 10000,
#  'wind': {'speed': 20.71, 'deg': 200, 'gust': 25.32},
#  'clouds': {'all': 20},
#  'dt': 1658417160,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1658395552,
#   'sunset': 1658448904},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
#Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tommot
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | la ronge
# Processing Record 5 of Set 1 | port-gentil
# Processing Record 6 of Set 1 | natal
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | kijang
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | umm kaddadah
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | comodoro rivadavia
# Processing Record 15 of Set 1 | mae ramat
# Processing Record 16 of Set 1 | jumla
# Processing Record 17 of Set 1 | margate
# Processing Record 18 of Set 1 | santo estevao
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | seoul
# Processing Record 21 of Set 1 | tiarei
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | odweyne
# Processing Record 24 of Set 1 | kremenchuk
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | andover
# Processing Record 29 of Set 1 | zhanaozen
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | lavrentiya
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | dingle
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | kargopol
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | aksarka
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | berlevag
# Processing Record 46 of Set 1 | deputatskiy
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | puerto asis
# Processing Record 49 of Set 1 | mabaruma
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | barcelos
# Processing Record 7 of Set 2 | khilok
# Processing Record 8 of Set 2 | gampaha
# Processing Record 9 of Set 2 | babushkin
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | swellendam
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | moron
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | pakxan
# Processing Record 20 of Set 2 | kankan
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | douentza
# Processing Record 23 of Set 2 | manavalakurichi
# Processing Record 24 of Set 2 | zheleznodorozhnyy
# Processing Record 25 of Set 2 | hay river
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | surt
# Processing Record 28 of Set 2 | pangnirtung
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 31 of Set 2 | cumra
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | clyde river
# Processing Record 36 of Set 2 | huarmey
# Processing Record 37 of Set 2 | coihueco
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | sterling
# Processing Record 41 of Set 2 | mogadishu
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | dalby
# Processing Record 44 of Set 2 | dubrovnik
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | acapulco
# Processing Record 47 of Set 2 | beloha
# Processing Record 48 of Set 2 | tynda
# Processing Record 49 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | west lafayette
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | bandraboua
# Processing Record 6 of Set 3 | labuhan
# Processing Record 7 of Set 3 | erie
# Processing Record 8 of Set 3 | virginia beach
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | ust-nera
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | suwa
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | lorengau
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | namatanai
# Processing Record 18 of Set 3 | egvekinot
# Processing Record 19 of Set 3 | dhidhdhoo
# Processing Record 20 of Set 3 | novikovo
# Processing Record 21 of Set 3 | togur
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | kalabo
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | qeshm
# Processing Record 27 of Set 3 | los mochis
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | zhigansk
# Processing Record 30 of Set 3 | kondinskoye
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | prince george
# Processing Record 34 of Set 3 | tabas
# Processing Record 35 of Set 3 | north bend
# Processing Record 36 of Set 3 | khorixas
# Processing Record 37 of Set 3 | beringovskiy
# Processing Record 38 of Set 3 | port macquarie
# Processing Record 39 of Set 3 | canyon
# Processing Record 40 of Set 3 | ewa beach
# Processing Record 41 of Set 3 | saint-augustin
# Processing Record 42 of Set 3 | naryan-mar
# Processing Record 43 of Set 3 | monywa
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | panaba
# Processing Record 46 of Set 3 | sabya
# Processing Record 47 of Set 3 | ginir
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | mazatlan
# Processing Record 50 of Set 3 | alghero
# Processing Record 1 of Set 4 | ocampo
# Processing Record 2 of Set 4 | nanortalik
# Processing Record 3 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 4 | ayr
# Processing Record 5 of Set 4 | nambucca heads
# Processing Record 6 of Set 4 | puerto montt
# Processing Record 7 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 4 | cerrito
# Processing Record 9 of Set 4 | vao
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | manchester
# Processing Record 12 of Set 4 | broome
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | stokmarknes
# Processing Record 15 of Set 4 | nhulunbuy
# Processing Record 16 of Set 4 | fjerritslev
# Processing Record 17 of Set 4 | beyneu
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | bengkulu
# Processing Record 20 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 4 | nisia floresta
# Processing Record 22 of Set 4 | ixtlahuacan del rio
# Processing Record 23 of Set 4 | guerrero negro
# Processing Record 24 of Set 4 | ostroleka
# Processing Record 25 of Set 4 | villa altagracia
# Processing Record 26 of Set 4 | abu samrah
# Processing Record 27 of Set 4 | progreso
# Processing Record 28 of Set 4 | bam
# Processing Record 29 of Set 4 | sangar
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | pokhvistnevo
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | saint george
# Processing Record 34 of Set 4 | ponta do sol
# Processing Record 35 of Set 4 | manitouwadge
# Processing Record 36 of Set 4 | san cristobal
# Processing Record 37 of Set 4 | aksu
# Processing Record 38 of Set 4 | kaitangata
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | saint-pierre
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | qaanaaq
# Processing Record 43 of Set 4 | altay
# Processing Record 44 of Set 4 | dalbandin
# Processing Record 45 of Set 4 | moranbah
# Processing Record 46 of Set 4 | revelstoke
# Processing Record 47 of Set 4 | durango
# Processing Record 48 of Set 4 | tondano
# Processing Record 49 of Set 4 | hilo
# Processing Record 50 of Set 4 | aleksandrov gay
# Processing Record 1 of Set 5 | ban nahin
# Processing Record 2 of Set 5 | rio grande
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | pouembout
# Processing Record 5 of Set 5 | batsfjord
# Processing Record 6 of Set 5 | rosetta
# Processing Record 7 of Set 5 | nuuk
# Processing Record 8 of Set 5 | cayenne
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | amalapuram
# Processing Record 12 of Set 5 | thiers
# Processing Record 13 of Set 5 | quzhou
# Processing Record 14 of Set 5 | verkhnevilyuysk
# Processing Record 15 of Set 5 | zhezkazgan
# Processing Record 16 of Set 5 | alofi
# Processing Record 17 of Set 5 | adrar
# Processing Record 18 of Set 5 | sinnamary
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | camacha
# Processing Record 21 of Set 5 | sola
# Processing Record 22 of Set 5 | hazorasp
# Processing Record 23 of Set 5 | iwanai
# Processing Record 24 of Set 5 | haines junction
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | kaeo
# Processing Record 27 of Set 5 | goderich
# Processing Record 28 of Set 5 | daoukro
# Processing Record 29 of Set 5 | colon
# Processing Record 30 of Set 5 | abha
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | wanning
# Processing Record 34 of Set 5 | vysokogornyy
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | mvuma
# Processing Record 37 of Set 5 | ola
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | kautokeino
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | oga
# Processing Record 43 of Set 5 | lufilufi
# Processing Record 44 of Set 5 | batatais
# Processing Record 45 of Set 5 | palimbang
# Processing Record 46 of Set 5 | requena
# Processing Record 47 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 5 | guilin
# Processing Record 49 of Set 5 | songjianghe
# Processing Record 50 of Set 5 | pevek
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | cap malheureux
# Processing Record 3 of Set 6 | pochutla
# Processing Record 4 of Set 6 | corinth
# Processing Record 5 of Set 6 | pran buri
# Processing Record 6 of Set 6 | campbell river
# Processing Record 7 of Set 6 | shieli
# Processing Record 8 of Set 6 | pokhara
# Processing Record 9 of Set 6 | rock sound
# Processing Record 10 of Set 6 | sorkjosen
# Processing Record 11 of Set 6 | sai buri
# Processing Record 12 of Set 6 | medea
# Processing Record 13 of Set 6 | kurikka
# Processing Record 14 of Set 6 | turbat
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | knyaginino
# Processing Record 17 of Set 6 | deep river
# Processing Record 18 of Set 6 | khatanga
# Processing Record 19 of Set 6 | madison
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | salinopolis
# Processing Record 22 of Set 6 | port lincoln
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | columbus
# Processing Record 25 of Set 6 | mahibadhoo
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | bo
# City not found. Skipping...
# Processing Record 28 of Set 6 | valley city
# Processing Record 29 of Set 6 | kavieng
# Processing Record 30 of Set 6 | leh
# Processing Record 31 of Set 6 | oussouye
# Processing Record 32 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 6 | saldanha
# Processing Record 37 of Set 6 | harper
# Processing Record 38 of Set 6 | krasnoselkup
# Processing Record 39 of Set 6 | bardiyah
# Processing Record 40 of Set 6 | tuatapere
# Processing Record 41 of Set 6 | beloomut
# Processing Record 42 of Set 6 | elat
# Processing Record 43 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 44 of Set 6 | longyearbyen
# Processing Record 45 of Set 6 | fortuna
# Processing Record 46 of Set 6 | jitia
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | beidao
# Processing Record 49 of Set 6 | manta
# Processing Record 50 of Set 6 | yemelyanovo
# Processing Record 1 of Set 7 | faanui
# Processing Record 2 of Set 7 | yaan
# Processing Record 3 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 7 | yar-sale
# Processing Record 5 of Set 7 | divo
# Processing Record 6 of Set 7 | kununurra
# Processing Record 7 of Set 7 | laplace
# Processing Record 8 of Set 7 | porto novo
# Processing Record 9 of Set 7 | san vicente
# Processing Record 10 of Set 7 | praia
# Processing Record 11 of Set 7 | teya
# Processing Record 12 of Set 7 | mackenzie
# Processing Record 13 of Set 7 | katsuura
# Processing Record 14 of Set 7 | coolum beach
# Processing Record 15 of Set 7 | gonen
# Processing Record 16 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 17 of Set 7 | marhaura
# Processing Record 18 of Set 7 | cabo san lucas
# Processing Record 19 of Set 7 | upernavik
# Processing Record 20 of Set 7 | fertorakos
# Processing Record 21 of Set 7 | avera
# Processing Record 22 of Set 7 | tonantins
# Processing Record 23 of Set 7 | tucuman
# Processing Record 24 of Set 7 | qandala
# Processing Record 25 of Set 7 | saskylakh
# Processing Record 26 of Set 7 | bucerias
# Processing Record 27 of Set 7 | gamba
# Processing Record 28 of Set 7 | trairi
# Processing Record 29 of Set 7 | asau
# Processing Record 30 of Set 7 | manokwari
# Processing Record 31 of Set 7 | fontanka
# Processing Record 32 of Set 7 | yerbogachen
# Processing Record 33 of Set 7 | khani
# Processing Record 34 of Set 7 | kenora
# Processing Record 35 of Set 7 | kulebaki
# Processing Record 36 of Set 7 | tshikapa
# Processing Record 37 of Set 7 | cabatuan
# Processing Record 38 of Set 7 | sao miguel do araguaia
# Processing Record 39 of Set 7 | sombrerete
# Processing Record 40 of Set 7 | tongchuan
# Processing Record 41 of Set 7 | muisne
# Processing Record 42 of Set 7 | paranaiba
# Processing Record 43 of Set 7 | chokwe
# Processing Record 44 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 45 of Set 7 | champerico
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | grindavik
# Processing Record 48 of Set 7 | canon city
# Processing Record 49 of Set 7 | oudtshoorn
# Processing Record 50 of Set 7 | saint-francois
# Processing Record 1 of Set 8 | hofn
# Processing Record 2 of Set 8 | ulagan
# Processing Record 3 of Set 8 | mackay
# Processing Record 4 of Set 8 | tsiroanomandidy
# Processing Record 5 of Set 8 | monte patria
# Processing Record 6 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | lebork
# Processing Record 9 of Set 8 | sao filipe
# Processing Record 10 of Set 8 | menongue
# Processing Record 11 of Set 8 | carnarvon
# Processing Record 12 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 13 of Set 8 | tabou
# Processing Record 14 of Set 8 | sao joao da barra
# Processing Record 15 of Set 8 | normandin
# Processing Record 16 of Set 8 | pudozh
# Processing Record 17 of Set 8 | marzuq
# Processing Record 18 of Set 8 | murmashi
# Processing Record 19 of Set 8 | oistins
# Processing Record 20 of Set 8 | dwarka
# Processing Record 21 of Set 8 | port moresby
# Processing Record 22 of Set 8 | chernyshevskiy
# Processing Record 23 of Set 8 | xunchang
# Processing Record 24 of Set 8 | jaciara
# Processing Record 25 of Set 8 | presque isle
# Processing Record 26 of Set 8 | olafsvik
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | uray
# Processing Record 29 of Set 8 | paranagua
# Processing Record 30 of Set 8 | nowa sol
# Processing Record 31 of Set 8 | college
# Processing Record 32 of Set 8 | westerland
# Processing Record 33 of Set 8 | orlik
# Processing Record 34 of Set 8 | wanaka
# Processing Record 35 of Set 8 | mabopane
# Processing Record 36 of Set 8 | tessalit
# Processing Record 37 of Set 8 | karatsu
# Processing Record 38 of Set 8 | kobryn
# Processing Record 39 of Set 8 | santiago del estero
# Processing Record 40 of Set 8 | shimoda
# Processing Record 41 of Set 8 | harrismith
# Processing Record 42 of Set 8 | eslamshahr
# Processing Record 43 of Set 8 | santa fe
# Processing Record 44 of Set 8 | marathopolis
# City not found. Skipping...
# Processing Record 45 of Set 8 | nuevo progreso
# Processing Record 46 of Set 8 | cabedelo
# Processing Record 47 of Set 8 | bastia
# Processing Record 48 of Set 8 | henties bay
# Processing Record 49 of Set 8 | gbadolite
# Processing Record 50 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 9 | cassilandia
# Processing Record 2 of Set 9 | gat
# Processing Record 3 of Set 9 | gladstone
# Processing Record 4 of Set 9 | cravo norte
# Processing Record 5 of Set 9 | thinadhoo
# Processing Record 6 of Set 9 | bacolod
# Processing Record 7 of Set 9 | paamiut
# Processing Record 8 of Set 9 | noumea
# Processing Record 9 of Set 9 | klaksvik
# Processing Record 10 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 9 | le havre
# Processing Record 12 of Set 9 | ankang
# Processing Record 13 of Set 9 | saint-philippe
# Processing Record 14 of Set 9 | qui nhon
# Processing Record 15 of Set 9 | salalah
# Processing Record 16 of Set 9 | mamit
# Processing Record 17 of Set 9 | dali
# Processing Record 18 of Set 9 | rio gallegos
# Processing Record 19 of Set 9 | pyay
# Processing Record 20 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 9 | robe
# Processing Record 22 of Set 9 | erzin
# Processing Record 23 of Set 9 | misratah
# Processing Record 24 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 9 | mozarlandia
# Processing Record 26 of Set 9 | chicama
# Processing Record 27 of Set 9 | pombas
# Processing Record 28 of Set 9 | shahreza
# Processing Record 29 of Set 9 | kotido
# Processing Record 30 of Set 9 | vanino
# Processing Record 31 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 9 | scarborough
# Processing Record 33 of Set 9 | san rafael
# Processing Record 34 of Set 9 | juneau
# Processing Record 35 of Set 9 | victoria
# Processing Record 36 of Set 9 | brae
# Processing Record 37 of Set 9 | bushehr
# Processing Record 38 of Set 9 | oranjemund
# Processing Record 39 of Set 9 | tehuacan
# Processing Record 40 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 9 | laguna
# Processing Record 42 of Set 9 | narsaq
# Processing Record 43 of Set 9 | puerto escondido
# Processing Record 44 of Set 9 | jalu
# Processing Record 45 of Set 9 | flin flon
# Processing Record 46 of Set 9 | wahiawa
# Processing Record 47 of Set 9 | robertsport
# Processing Record 48 of Set 9 | mayo
# Processing Record 49 of Set 9 | hambantota
# Processing Record 50 of Set 9 | kingsville
# Processing Record 1 of Set 10 | eureka
# Processing Record 2 of Set 10 | hamilton
# Processing Record 3 of Set 10 | santana do livramento
# Processing Record 4 of Set 10 | amahai
# Processing Record 5 of Set 10 | alta floresta
# Processing Record 6 of Set 10 | sao raimundo das mangabeiras
# Processing Record 7 of Set 10 | synya
# Processing Record 8 of Set 10 | auki
# Processing Record 9 of Set 10 | kisangani
# Processing Record 10 of Set 10 | bandundu
# Processing Record 11 of Set 10 | karratha
# Processing Record 12 of Set 10 | kodinsk
# Processing Record 13 of Set 10 | ahuimanu
# Processing Record 14 of Set 10 | vila velha
# Processing Record 15 of Set 10 | kerouane
# Processing Record 16 of Set 10 | pitimbu
# Processing Record 17 of Set 10 | hami
# Processing Record 18 of Set 10 | makakilo city
# Processing Record 19 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 10 | kaniama
# Processing Record 21 of Set 10 | payson
# Processing Record 22 of Set 10 | phan thiet
# Processing Record 23 of Set 10 | mayskiy
# Processing Record 24 of Set 10 | kapit
# Processing Record 25 of Set 10 | foumban
# Processing Record 26 of Set 10 | maraa
# Processing Record 27 of Set 10 | bluefield
# Processing Record 28 of Set 10 | werda
# Processing Record 29 of Set 10 | tamandare
# Processing Record 30 of Set 10 | manono
# Processing Record 31 of Set 10 | ketchikan
# Processing Record 32 of Set 10 | inverness
# Processing Record 33 of Set 10 | ulcinj
# Processing Record 34 of Set 10 | dese
# Processing Record 35 of Set 10 | koshurnikovo
# Processing Record 36 of Set 10 | kota bahru
# Processing Record 37 of Set 10 | monrovia
# Processing Record 38 of Set 10 | matamoros
# Processing Record 39 of Set 10 | rengali
# Processing Record 40 of Set 10 | forio
# Processing Record 41 of Set 10 | ambunti
# Processing Record 42 of Set 10 | christchurch
# Processing Record 43 of Set 10 | xining
# Processing Record 44 of Set 10 | yelizovo
# Processing Record 45 of Set 10 | garowe
# Processing Record 46 of Set 10 | pompeu
# Processing Record 47 of Set 10 | kirakira
# Processing Record 48 of Set 10 | ixtapa
# Processing Record 49 of Set 10 | buin
# Processing Record 50 of Set 10 | tiksi
# Processing Record 1 of Set 11 | baguinge
# Processing Record 2 of Set 11 | traverse city
# Processing Record 3 of Set 11 | macklin
# Processing Record 4 of Set 11 | akdepe
# Processing Record 5 of Set 11 | zhanakorgan
# Processing Record 6 of Set 11 | bella vista
# Processing Record 7 of Set 11 | chiang klang
# Processing Record 8 of Set 11 | partapur
# Processing Record 9 of Set 11 | sitka
# Processing Record 10 of Set 11 | libertador general san martin
# Processing Record 11 of Set 11 | palana
# Processing Record 12 of Set 11 | yumen
# Processing Record 13 of Set 11 | ereymentau
# Processing Record 14 of Set 11 | pandan
# Processing Record 15 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 11 | bikaner
# Processing Record 17 of Set 11 | carbonia
# Processing Record 18 of Set 11 | cervo
# Processing Record 19 of Set 11 | mkushi
# Processing Record 20 of Set 11 | gorom-gorom
# Processing Record 21 of Set 11 | whitianga
# Processing Record 22 of Set 11 | valdivia
# Processing Record 23 of Set 11 | northam
# Processing Record 24 of Set 11 | vaitape
# Processing Record 25 of Set 11 | puteyets
# Processing Record 26 of Set 11 | carutapera
# Processing Record 27 of Set 11 | voyvozh
# Processing Record 28 of Set 11 | catuday
# Processing Record 29 of Set 11 | sesheke
# Processing Record 30 of Set 11 | vanimo
# Processing Record 31 of Set 11 | navabad
# City not found. Skipping...
# Processing Record 32 of Set 11 | raudeberg
# Processing Record 33 of Set 11 | shimanovsk
# Processing Record 34 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 11 | opuwo
# Processing Record 36 of Set 11 | arawa
# Processing Record 37 of Set 11 | rafai
# Processing Record 38 of Set 11 | camana
# Processing Record 39 of Set 11 | havre-saint-pierre
# Processing Record 40 of Set 11 | ustye
# Processing Record 41 of Set 11 | doka
# Processing Record 42 of Set 11 | elizabethton
# Processing Record 43 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 11 | meridian
# Processing Record 45 of Set 11 | gushi
# Processing Record 46 of Set 11 | vallenar
# Processing Record 47 of Set 11 | hobyo
# Processing Record 48 of Set 11 | port-cartier
# Processing Record 49 of Set 11 | kokopo
# Processing Record 50 of Set 11 | roma
# Processing Record 1 of Set 12 | richards bay
# Processing Record 2 of Set 12 | conde
# Processing Record 3 of Set 12 | linfen
# Processing Record 4 of Set 12 | vung tau
# Processing Record 5 of Set 12 | saint-louis
# Processing Record 6 of Set 12 | bathsheba
# Processing Record 7 of Set 12 | soyo
# Processing Record 8 of Set 12 | kashi
# Processing Record 9 of Set 12 | evanston
# Processing Record 10 of Set 12 | sukhobezvodnoye
# Processing Record 11 of Set 12 | karaton
# Processing Record 12 of Set 12 | kargasok
# Processing Record 13 of Set 12 | delijan
# Processing Record 14 of Set 12 | chipiona
# Processing Record 15 of Set 12 | hirado
# Processing Record 16 of Set 12 | guanica
# Processing Record 17 of Set 12 | samarai
# Processing Record 18 of Set 12 | hualmay
# Processing Record 19 of Set 12 | coihaique
# Processing Record 20 of Set 12 | rabo de peixe
# Processing Record 21 of Set 12 | verkhoyansk
# Processing Record 22 of Set 12 | shenjiamen
# Processing Record 23 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 12 | hoopstad
# Processing Record 25 of Set 12 | grafton
# Processing Record 26 of Set 12 | mafra
# Processing Record 27 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 12 | nishihara
# Processing Record 29 of Set 12 | lagoa
# Processing Record 30 of Set 12 | tezu
# Processing Record 31 of Set 12 | artyom
# Processing Record 32 of Set 12 | langham
# Processing Record 33 of Set 12 | yingcheng
# Processing Record 34 of Set 12 | umea
# Processing Record 35 of Set 12 | bud
# Processing Record 36 of Set 12 | lerwick
# Processing Record 37 of Set 12 | athabasca
# Processing Record 38 of Set 12 | chumikan
# Processing Record 39 of Set 12 | birigui
# Processing Record 40 of Set 12 | warmbad
# Processing Record 41 of Set 12 | santa cruz
# Processing Record 42 of Set 12 | astoria
# Processing Record 43 of Set 12 | gorey
# Processing Record 44 of Set 12 | manado
# Processing Record 45 of Set 12 | ostrovnoy
# Processing Record 46 of Set 12 | tadine
# Processing Record 47 of Set 12 | la libertad
# Processing Record 48 of Set 12 | perpignan
# Processing Record 49 of Set 12 | semiletka
# Processing Record 50 of Set 12 | golden rock
# City not found. Skipping...
# Processing Record 1 of Set 13 | kinablangan
# Processing Record 2 of Set 13 | skibbereen
# Processing Record 3 of Set 13 | derbent
# Processing Record 4 of Set 13 | tual
# Processing Record 5 of Set 13 | fairbanks
# Processing Record 6 of Set 13 | valreas
# Processing Record 7 of Set 13 | okakarara
# Processing Record 8 of Set 13 | saint-joseph
# Processing Record 9 of Set 13 | gobabis
# Processing Record 10 of Set 13 | billings
# Processing Record 11 of Set 13 | sioux lookout
# Processing Record 12 of Set 13 | caravelas
# Processing Record 13 of Set 13 | constitucion
# Processing Record 14 of Set 13 | lashio
# Processing Record 15 of Set 13 | coxim
# Processing Record 16 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 13 | faya
# Processing Record 18 of Set 13 | srandakan
# Processing Record 19 of Set 13 | kostenec
# City not found. Skipping...
# Processing Record 20 of Set 13 | juba
# Processing Record 21 of Set 13 | bac lieu
# Processing Record 22 of Set 13 | panguna
# Processing Record 23 of Set 13 | vila
# Processing Record 24 of Set 13 | badvel
# Processing Record 25 of Set 13 | sarangani
# Processing Record 26 of Set 13 | tagab
# Processing Record 27 of Set 13 | camargo
# Processing Record 28 of Set 13 | rodbyhavn
# Processing Record 29 of Set 13 | skelleftea
# Processing Record 30 of Set 13 | ulaangom
# Processing Record 31 of Set 13 | dickinson
# Processing Record 32 of Set 13 | afgoye
# City not found. Skipping...
# Processing Record 33 of Set 13 | los llanos de aridane
# Processing Record 34 of Set 13 | aitape
# Processing Record 35 of Set 13 | baykit
# Processing Record 36 of Set 13 | ndele
# Processing Record 37 of Set 13 | murgab
# Processing Record 38 of Set 13 | hervey bay
# Processing Record 39 of Set 13 | fallon
# Processing Record 40 of Set 13 | ipeti
# City not found. Skipping...
# Processing Record 41 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 13 | san quintin
# Processing Record 43 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 13 | jacksonville
# Processing Record 45 of Set 13 | samarina
# Processing Record 46 of Set 13 | camacupa
# Processing Record 47 of Set 13 | portland
# Processing Record 48 of Set 13 | tura
# Processing Record 49 of Set 13 | dong xoai
# Processing Record 50 of Set 13 | daru
# Processing Record 1 of Set 14 | kushima
# Processing Record 2 of Set 14 | alibag
# Processing Record 3 of Set 14 | maarianhamina
# Processing Record 4 of Set 14 | mount isa
# Processing Record 5 of Set 14 | prince rupert
# Processing Record 6 of Set 14 | kudahuvadhoo
# Processing Record 7 of Set 14 | hirara
# Processing Record 8 of Set 14 | walvis bay
# Processing Record 9 of Set 14 | les cayes
# Processing Record 10 of Set 14 | sabha
# Processing Record 11 of Set 14 | mongo
# Processing Record 12 of Set 14 | moerai
# Processing Record 13 of Set 14 | nadvoitsy
# Processing Record 14 of Set 14 | san carlos de bariloche
# Processing Record 15 of Set 14 | kuusamo
# Processing Record 16 of Set 14 | santa vitoria do palmar
# Processing Record 17 of Set 14 | lebedinyy
# Processing Record 18 of Set 14 | zabol
# Processing Record 19 of Set 14 | gazojak
# Processing Record 20 of Set 14 | waipawa
# Processing Record 21 of Set 14 | shihezi
# Processing Record 22 of Set 14 | srednekolymsk
# Processing Record 23 of Set 14 | komsomolskiy
# Processing Record 24 of Set 14 | puri
# Processing Record 25 of Set 14 | myitkyina
# Processing Record 26 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 27 of Set 14 | aguimes
# Processing Record 28 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 14 | burica
# City not found. Skipping...
# Processing Record 30 of Set 14 | bilibino
# Processing Record 31 of Set 14 | sao jose da coroa grande
# Processing Record 32 of Set 14 | banepa
# Processing Record 33 of Set 14 | muli
# Processing Record 34 of Set 14 | hun
# Processing Record 35 of Set 14 | usinsk
# Processing Record 36 of Set 14 | arenapolis
# Processing Record 37 of Set 14 | weligama
# Processing Record 38 of Set 14 | sunam
# Processing Record 39 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 14 | diffa
# Processing Record 41 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 14 | mayor pablo lagerenza
# Processing Record 43 of Set 14 | vostok
# Processing Record 44 of Set 14 | poros
# Processing Record 45 of Set 14 | ust-kuyga
# Processing Record 46 of Set 14 | punta alta
# Processing Record 47 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 48 of Set 14 | taree
# Processing Record 49 of Set 14 | bandhi
# Processing Record 50 of Set 14 | cochrane
# Processing Record 1 of Set 15 | ishigaki
# Processing Record 2 of Set 15 | chilca
# Processing Record 3 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 5 of Set 15 | sobolevo
# Processing Record 6 of Set 15 | kangaatsiaq
# Processing Record 7 of Set 15 | hovd
# Processing Record 8 of Set 15 | vardo
# Processing Record 9 of Set 15 | fairfield
# Processing Record 10 of Set 15 | madang
# Processing Record 11 of Set 15 | goias
# Processing Record 12 of Set 15 | birao
# Processing Record 13 of Set 15 | keti bandar
# Processing Record 14 of Set 15 | maningrida
# Processing Record 15 of Set 15 | mercedes
# Processing Record 16 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 15 | sainte-rose
# Processing Record 18 of Set 15 | quang ngai
# Processing Record 19 of Set 15 | yoichi
# Processing Record 20 of Set 15 | bonavista
# Processing Record 21 of Set 15 | kieta
# Processing Record 22 of Set 15 | hong gai
# Processing Record 23 of Set 15 | kainantu
# Processing Record 24 of Set 15 | rivne
# Processing Record 25 of Set 15 | jibuti
# Processing Record 26 of Set 15 | oconomowoc
# Processing Record 27 of Set 15 | mitsamiouli
# Processing Record 28 of Set 15 | makat
# Processing Record 29 of Set 15 | stornoway
# Processing Record 30 of Set 15 | kihei
# Processing Record 31 of Set 15 | namie
# Processing Record 32 of Set 15 | deniliquin
# Processing Record 33 of Set 15 | nantucket
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 15 | itarema
# Processing Record 37 of Set 15 | tazmalt
# Processing Record 38 of Set 15 | ziarat
# Processing Record 39 of Set 15 | puerto del rosario
# Processing Record 40 of Set 15 | kasongo
# Processing Record 41 of Set 15 | luang prabang
# Processing Record 42 of Set 15 | sirpur
# Processing Record 43 of Set 15 | itoman
# Processing Record 44 of Set 15 | baghdad
# Processing Record 45 of Set 15 | ambon
# Processing Record 46 of Set 15 | waingapu
# Processing Record 47 of Set 15 | kalmunai
# Processing Record 48 of Set 15 | sisimiut
# Processing Record 49 of Set 15 | beaverlodge
# Processing Record 50 of Set 15 | llallagua
# Processing Record 1 of Set 16 | punta umbria
# Processing Record 2 of Set 16 | sinegorye
# Processing Record 3 of Set 16 | paka
# Processing Record 4 of Set 16 | terrace
# Processing Record 5 of Set 16 | shirokiy
# Processing Record 6 of Set 16 | wembley
# Processing Record 7 of Set 16 | taksimo
# Processing Record 8 of Set 16 | dom pedrito
# Processing Record 9 of Set 16 | obo
# Processing Record 10 of Set 16 | zahir pir
# Processing Record 11 of Set 16 | barmer
# Processing Record 12 of Set 16 | hiji
# Processing Record 13 of Set 16 | coquimbo
# Processing Record 14 of Set 16 | praia da vitoria
# Processing Record 15 of Set 16 | okato
# Processing Record 16 of Set 16 | patos
# Processing Record 17 of Set 16 | linxia
# Processing Record 18 of Set 16 | eenhana
# Processing Record 19 of Set 16 | himora
# City not found. Skipping...
# Processing Record 20 of Set 16 | sa kaeo
# Processing Record 21 of Set 16 | vestmannaeyjar
# Processing Record 22 of Set 16 | maltahohe
# Processing Record 23 of Set 16 | qasigiannguit
# Processing Record 24 of Set 16 | quelimane
# Processing Record 25 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 26 of Set 16 | tukrah
# Processing Record 27 of Set 16 | nakhon si thammarat
# Processing Record 28 of Set 16 | ittiri
# Processing Record 29 of Set 16 | oriximina
# Processing Record 30 of Set 16 | arua
# Processing Record 31 of Set 16 | tautira
# Processing Record 32 of Set 16 | mosquera
# Processing Record 33 of Set 16 | kannur
# Processing Record 34 of Set 16 | iquique
# Processing Record 35 of Set 16 | salamiyah
# Processing Record 36 of Set 16 | victoria point
# Processing Record 37 of Set 16 | xinqing
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tommot      RU  58.9564  126.2925     60.22        93           1
# 1     Jamestown      US  42.0970  -79.2353     79.02        77         100
# 2         Bluff      NZ -46.6000  168.3333     40.80        77         100
# 3      La Ronge      CA  55.1001 -105.2842     61.02        67         100
# 4   Port-Gentil      GA  -0.7193    8.7815     80.56        74          40
# 5         Natal      BR  -5.7950  -35.2094     86.22        66          75
# 6        Kijang      KR  35.2442  129.2139     78.53        81           1
# 7  Punta Arenas      CL -53.1500  -70.9167     33.91        86          20
# 8  Umm Kaddadah      SD  13.6017   26.6876     76.73        60         100
# 9     Hithadhoo      MV  -0.6000   73.0833     81.82        70         100
#
#    Wind Speed       Description
# 0        2.71         clear sky
# 1       14.97   overcast clouds
# 2        6.53   overcast clouds
# 3       21.85   overcast clouds
# 4       14.97  scattered clouds
# 5       13.80     broken clouds
# 6        6.85         clear sky
# 7       17.27        few clouds
# 8        8.14   overcast clouds
# 9        5.21   overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"

# %%
city_data_df.to_csv(output_data_file, index_label = "City_ID")
